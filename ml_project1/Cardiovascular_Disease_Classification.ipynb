# %% [markdown]
# # Cardiovascular Disease Classification

# %% [markdown]
# ## Import Libraries

# %%
# Import needed libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import re

from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report, make_scorer

from plotly.offline import iplot
import plotly as py
import plotly.tools as tls

import pickle

# %% [markdown]
# ## 1. Data Preparation and Data Exploration

# %%
# Read data in the excel file
df = pd.read_csv('data.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   70    1   4       130   322    0        2      109      0      2.4      2
# 1   67    0   3       115   564    0        2      160      0      1.6      2
# 2   57    1   2       124   261    0        0      141      0      0.3      1
# 3   64    1   4       128   263    0        0      105      1      0.2      2
# 4   74    0   2       120   269    0        2      121      1      0.2      1
#
#    ca  thal  target
# 0   3     3       2
# 1   0     7       1
# 2   0     7       2
# 3   1     7       1
# 4   1     3       1

# %%
df.tail()
# Out:
#      age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  \
# 265   52    1   3       172   199    1        0      162      0      0.5
# 266   44    1   2       120   263    0        0      173      0      0.0
# 267   56    0   2       140   294    0        2      153      0      1.3
# 268   57    1   4       140   192    0        0      148      0      0.4
# 269   67    1   4       160   286    0        2      108      1      1.5
#
#      slope  ca  thal  target
# 265      1   0     7       1
# 266      1   0     7       1
# 267      2   0     3       1
# 268      2   0     6       1
# 269      2   3     3       2

# %%
df.shape
# Out:
# (270, 14)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 270 entries, 0 to 269
# Data columns (total 14 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   age       270 non-null    int64
#  1   sex       270 non-null    int64
#  2   cp        270 non-null    int64
#  3   trestbps  270 non-null    int64
#  4   chol      270 non-null    int64
#  5   fbs       270 non-null    int64
#  6   restecg   270 non-null    int64
#  7   thalach   270 non-null    int64
#  8   exang     270 non-null    int64
#  9   oldpeak   270 non-null    float64
#  10  slope     270 non-null    int64
#  11  ca        270 non-null    int64
#  12  thal      270 non-null    int64
#  13  target    270 non-null    int64
# dtypes: float64(1), int64(13)
# memory usage: 29.7 KB

# %%
df.describe()
# Out:
#               age         sex          cp    trestbps        chol         fbs  \
# count  270.000000  270.000000  270.000000  270.000000  270.000000  270.000000
# mean    54.433333    0.677778    3.174074  131.344444  249.659259    0.148148
# std      9.109067    0.468195    0.950090   17.861608   51.686237    0.355906
# min     29.000000    0.000000    1.000000   94.000000  126.000000    0.000000
# 25%     48.000000    0.000000    3.000000  120.000000  213.000000    0.000000
# 50%     55.000000    1.000000    3.000000  130.000000  245.000000    0.000000
# 75%     61.000000    1.000000    4.000000  140.000000  280.000000    0.000000
# max     77.000000    1.000000    4.000000  200.000000  564.000000    1.000000
#
#           restecg     thalach       exang    oldpeak       slope          ca  \
# count  270.000000  270.000000  270.000000  270.00000  270.000000  270.000000
# mean     1.022222  149.677778    0.329630    1.05000    1.585185    0.670370
# std      0.997891   23.165717    0.470952    1.14521    0.614390    0.943896
# min      0.000000   71.000000    0.000000    0.00000    1.000000    0.000000
# 25%      0.000000  133.000000    0.000000    0.00000    1.000000    0.000000
# 50%      2.000000  153.500000    0.000000    0.80000    2.000000    0.000000
# 75%      2.000000  166.000000    1.000000    1.60000    2.000000    1.000000
# max      2.000000  202.000000    1.000000    6.20000    3.000000    3.000000
#
#              thal      target
# count  270.000000  270.000000
# mean     4.696296    1.444444
# std      1.940659    0.497827
# min      3.000000    1.000000
# 25%      3.000000    1.000000
# 50%      3.000000    1.000000
# 75%      7.000000    2.000000
# max      7.000000    2.000000

# %%
#Check null values
df.isnull().sum()
# Out:
# age         0
# sex         0
# cp          0
# trestbps    0
# chol        0
# fbs         0
# restecg     0
# thalach     0
# exang       0
# oldpeak     0
# slope       0
# ca          0
# thal        0
# target      0
# dtype: int64

# %%
df['target'].value_counts()
# Out:
# 1    150
# 2    120
# Name: target, dtype: int64

# %%
# Percentage of patients have and do not have heart disease
df['target'].value_counts()/df.shape[0]*100
# Out:
# 1    55.555556
# 2    44.444444
# Name: target, dtype: float64

# %%
# Create a plot to display the percentage of the positive and negative heart disease

labels = ['Yes','No']
value = df['target'].value_counts().values

plt.pie(value, labels=labels, autopct='%1.0f%%')
plt.title('Cardiovascular_Disease')
plt.show()

# %% [markdown]
# **Note:**
#
# As you can see, the dataset contains 14 columns 5 of them are numerical values and 9 of them are categorical values. We can see also there are no missing values in this dataset. As for the data balancing, the data is relatively balanced, 56% of the persons in the dataset have Cardiovascular disease.

# %% [markdown]
# ### Attributes Correlation

# %%
# Correlation map
plt.figure(figsize=(15, 15))
plt.title('Correlation between variables', color="Black",fontsize=15)
sns.heatmap(df.corr(),annot = True, cmap = "Blues")
plt.show()

# %% [markdown]
# ### Age Exploration

# %%
# Display age distribution
df['age'].plot(kind = 'hist', title = 'Age Distribution')
plt.show()

# %%
# Get min, max and average of the age
print('Min age: ', min(df['age']))
print('Max age: ', max(df['age']))
print('Average age: ', df['age'].mean())
# Out:
# Min age:  29
# Max age:  77
# Average age:  54.43333333333333

# %%
# Display age distribution based on heart disease
sns.histplot(df[df['target'] == 1]['age'], label='Do not have Cardiovascular disease')
sns.histplot(df[df['target'] == 2]['age'], label = 'Have Cardiovascular disease')
plt.xlabel('Frequency')
plt.ylabel('Age')
plt.title('Age Distribution based on Cardiovascular Disease')
plt.legend()
plt.show()

# %%
# Get min, max and average of the age of the people do not have Cardiovascular diseas
print('Min age of people who do not have Cardiovascular disease: ', min(df[df['target'] == 1]['age']))
print('Max age of people who do not have Cardiovascular disease: ', max(df[df['target'] == 1]['age']))
print('Average age of people who do not have Cardiovascular disease: ', df[df['target'] == 1]['age'].mean())
# Out:
# Min age of people who do not have Cardiovascular disease:  29
# Max age of people who do not have Cardiovascular disease:  76
# Average age of people who do not have Cardiovascular disease:  52.70666666666666

# %%
# Get min, max and average of the age of the people have heart diseas
print('Min age of people who have Cardiovascular disease: ', min(df[df['target'] == 2]['age']))
print('Max age of people who have Cardiovascular disease: ', max(df[df['target'] == 2]['age']))
print('Average age of people who have Cardiovascular disease: ', df[df['target'] == 2]['age'].mean())
# Out:
# Min age of people who have Cardiovascular disease:  35
# Max age of people who have Cardiovascular disease:  77
# Average age of people who have Cardiovascular disease:  56.59166666666667

# %% [markdown]
# ### Gender Exploration

# %%
# Number of males and females
F = df[df['sex'] == 0].count()['target']
M = df[df['sex'] == 1].count()['target']

# Create a plot
figure, ax = plt.subplots(figsize = (6, 4))
ax.bar(x = ['Female', 'Male'], height = [F, M])
plt.xlabel('Gender')
plt.title('Number of Males and Females in the dataset')
plt.show()

# %% [markdown]
# ### Chest Pain Type Exploration

# %%
# Display chest pain types in bar chart
df.groupby(df['cp']).count()['target'].plot(kind = 'bar', title = 'Chest Pain Types', figsize = (8, 6))
plt.xlabel('Chest Pain Types')
plt.xticks(np.arange(4), ('typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic'), rotation = 0)
plt.show()

# %%
# Display chest pain types based on the target
pd.crosstab(df.cp,df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Cardiovascular Disease Frequency According to Chest Pain Type')
plt.xlabel('Chest Pain Type')
plt.xticks(np.arange(4), ('typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic'), rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Blood Pressure Exploration

# %%
# Display blood pressure distribution
df['trestbps'].plot(kind = 'hist', title = 'Blood Pressure in mm Hg', figsize = (8, 6))
plt.show()

# %%
# Display blood pressure distribution based on heart disease
fig, (axis1, axis2) = plt.subplots(1, 2,figsize=(25, 5))
ax = sns.histplot(df[df['target'] == 1]['trestbps'], label='Do not have Cardiovascular disease', ax = axis1)
ax.set(xlabel='People Do Not Have Cardiovascular Disease')
ax = sns.histplot(df[df['target'] == 2]['trestbps'], label = 'Have Cardiovascular disease', ax = axis2)
ax.set(xlabel='People Have Cardiovascular Disease')
plt.show()

# %%
# Get min, max and average of the  blood pressure of the people do not have heart diseas
print('Min blood pressure of people who do not have Cardiovascular disease: ', min(df[df['target'] == 1]['trestbps']))
print('Max blood pressure of people who do not have Cardiovascular disease: ', max(df[df['target'] == 1]['trestbps']))
print('Average blood pressure of people who do not have Cardiovascular disease: ', df[df['target'] == 1]['trestbps'].mean())
# Out:
# Min blood pressure of people who do not have Cardiovascular disease:  94
# Max blood pressure of people who do not have Cardiovascular disease:  180
# Average blood pressure of people who do not have Cardiovascular disease:  128.86666666666667

# %%
# Get min, max and average of the blood pressure of the people have heart diseas
print('Min blood pressure of people who have Cardiovascular disease: ', min(df[df['target'] == 2]['trestbps']))
print('Max blood pressure of people who have Cardiovascular disease: ', max(df[df['target'] == 2]['trestbps']))
print('Average blood pressure of people who have Cardiovascular disease: ', df[df['target'] == 2]['trestbps'].mean())
# Out:
# Min blood pressure of people who have Cardiovascular disease:  100
# Max blood pressure of people who have Cardiovascular disease:  200
# Average blood pressure of people who have Cardiovascular disease:  134.44166666666666

# %% [markdown]
# ### Cholestoral Exploration

# %%
# Display Cholestoral distribution
df['chol'].plot(kind = 'hist', title = 'Serum Cholestoral in mg/dl', figsize = (8, 6))
plt.show()

# %%
# Display Cholestoral distribution based on heart disease
fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(25, 5))
ax = sns.histplot(df[df['target'] == 1]['chol'], label='Do not have Cardiovascular disease', ax = axis1)
ax.set(xlabel='People Do Not Have Cardiovascular Disease')
ax = sns.histplot(df[df['target'] == 2]['chol'], label = 'Have Cardiovascular disease', ax = axis2)
ax.set(xlabel='People Have Cardiovascular Disease')
plt.show()

# %%
# Get min, max and average of the Cholestoral of the people do not have heart diseas
print('Min cholestoral of people who do not have Cardiovascular disease: ', min(df[df['target'] == 1]['chol']))
print('Max cholestoral of people who do not have Cardiovascular disease: ', max(df[df['target'] == 1]['chol']))
print('Average cholestoral of people who do not have Cardiovascular disease: ', df[df['target'] == 1]['chol'].mean())
# Out:
# Min cholestoral of people who do not have Cardiovascular disease:  126
# Max cholestoral of people who do not have Cardiovascular disease:  564
# Average cholestoral of people who do not have Cardiovascular disease:  244.21333333333334

# %%
# Get min, max and average of the Cholestoral of the people have Cardiovascular diseas
print('Min cholestoral of people who have Cardiovascular disease: ', min(df[df['target'] == 2]['chol']))
print('Max cholestoral of people who have Cardiovascular disease: ', max(df[df['target'] == 2]['chol']))
print('Average cholestorale of people who have Cardiovascular disease: ', df[df['target'] == 2]['chol'].mean())
# Out:
# Min cholestoral of people who have Cardiovascular disease:  149
# Max cholestoral of people who have Cardiovascular disease:  409
# Average cholestorale of people who have Cardiovascular disease:  256.46666666666664

# %% [markdown]
# ### Fasting Blood Sugar  Exploration

# %%
# Display fasting blood sugar in bar chart
df.groupby(df['fbs']).count()['target'].plot(kind = 'bar', title = 'Fasting Blood Sugar', figsize = (8, 6))
plt.xticks(np.arange(2), ('fbs < 120 mg/dl', 'fbs > 120 mg/dl'), rotation = 0)
plt.show()

# %%
# Display fasting blood sugar based on the target
pd.crosstab(df.fbs,df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Cardiovascular Disease Frequency According to Fasting Blood Sugar')
plt.xlabel('Fasting Blood Sugar')
plt.xticks(np.arange(2), ('fbs < 120 mg/dl', 'fbs > 120 mg/dl'), rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ###  Electrocardiographic Results Exploration

# %%
# Display electrocardiographic results in bar chart
df.groupby(df['restecg']).count()['target'].plot(kind = 'bar', title = 'Resting Electrocardiographic Results', figsize = (8, 6))
plt.xticks(np.arange(3), ('normal', 'ST-T wave abnormality', 'probable or left ventricular hypertrophy'))
plt.show()

# %%
# Display resting electrocardiographic results based on the target
pd.crosstab(df.restecg,df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Cardiovascular Disease Frequency According to Resting Electrocardiographic Results')
plt.xticks(np.arange(3), ('normal', 'ST-T wave abnormality', 'probable or left ventricular hypertrophy'))
plt.xlabel('Resting Electrocardiographic Results')
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# ### Maximum Heart Rate Exploration

# %%
# Display maximum heart rate distribution
df['thalach'].plot(kind = 'hist', title = 'Maximum Heart Rate Achieved', figsize = (8, 6))
plt.show()

# %%
# Display maximum heart rate distribution based on heart disease
fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(25, 5))
ax = sns.histplot(df[df['target'] == 1]['thalach'], label='Do not have Cardiovascular disease', ax = axis1)
ax.set(xlabel = 'People Do Not Have Cardiovascular Disease')
ax = sns.histplot(df[df['target'] == 2]['thalach'], label = 'Have Cardiovascular disease', ax = axis2)
ax.set(xlabel = 'People Have Cardiovascular Disease')
plt.show()

# %%
# Get min, max and average of the maximum heart rate of the people do not have heart diseas
print('Min resting blood pressure of people who do not have Cardiovascular disease: ', min(df[df['target'] == 1]['thalach']))
print('Max resting blood pressure of people who do not have Cardiovascular disease: ', max(df[df['target'] == 1]['thalach']))
print('Average resting blood pressure of people who do not have Cardiovascular disease: ', df[df['target'] == 1]['thalach'].mean())
# Out:
# Min resting blood pressure of people who do not have Cardiovascular disease:  96
# Max resting blood pressure of people who do not have Cardiovascular disease:  202
# Average resting blood pressure of people who do not have Cardiovascular disease:  158.33333333333334

# %%
# Get min, max and average of the maximum heart rate of the people have heart diseas
print('Min maximum heart rate  of people who have Cardiovascular disease: ', min(df[df['target'] == 2]['thalach']))
print('Max maximum heart rate people who have Cardiovascular disease: ', max(df[df['target'] == 2]['thalach']))
print('Average maximum heart rate of people who have Cardiovascular disease: ', df[df['target'] == 2]['thalach'].mean())
# Out:
# Min maximum heart rate  of people who have Cardiovascular disease:  71
# Max maximum heart rate people who have Cardiovascular disease:  195
# Average maximum heart rate of people who have Cardiovascular disease:  138.85833333333332

# %% [markdown]
# **Note:**
#
# The people who have heigh heart rate greater than 150 are more likely to have heart disease.

# %% [markdown]
# ### Exercise Induced Angina Exploration

# %%
# Display exercise induced angina in bar chart
df.groupby(df['exang']).count()['target'].plot(kind = 'bar', title = 'Exercise Induced Angina',  figsize = (8, 6))
plt.xticks(np.arange(2), ('No', 'Yes'), rotation = 0)
plt.show()

# %%
# Display exercise induced angina based on the target
pd.crosstab(df.exang,df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Cardiovascular Disease Frequency According to Exercise Induced Angina')
plt.xlabel('Exercise Induced Angina')
plt.xticks(np.arange(2), ('No', 'Yes'), rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Note:**
#
# The people who suffer from exercise induced angina are more likely to likely to be infected with the heart disease.

# %% [markdown]
# ### ST depression Exploration

# %%
# Display ST depression induced by exercise relative to rest distribution
df['oldpeak'].plot(kind = 'hist', title = 'ST Depression Induced by Exercise Relative to Rest', figsize = (8, 6))
plt.show()

# %%
# Display ST depression distribution based on heart disease
fig, (axis1, axis2) = plt.subplots(1, 2, figsize=(25, 5))
ax = sns.histplot(df[df['target'] == 1]['oldpeak'], label='Do not have Cardiovascular disease', ax = axis1)
ax.set(xlabel = 'People Do Not Have Cardiovascular Disease')
ax = sns.histplot(df[df['target'] == 2]['oldpeak'], label = 'Have Cardiovascular disease', ax = axis2)
ax.set(xlabel = 'People Have Cardiovascular Disease')
plt.show()

# %%
# Get min, max and average of the ST depression  of the people have heart diseas
print('Min ST depression of people who do not have Cardiovascular disease: ', min(df[df['target'] == 1]['oldpeak']))
print('Max ST depression of people who do not have Cardiovascular disease: ', max(df[df['target'] == 1]['oldpeak']))
print('Average ST depression of people who do not have Cardiovascular disease: ', df[df['target'] == 1]['oldpeak'].mean())
# Out:
# Min ST depression of people who do not have Cardiovascular disease:  0.0
# Max ST depression of people who do not have Cardiovascular disease:  4.2
# Average ST depression of people who do not have Cardiovascular disease:  0.6226666666666668

# %%
# Get min, max and average of the ST depression of the people have heart diseas
print('Min ST depression of people who have Cardiovascular disease: ', min(df[df['target'] == 2]['oldpeak']))
print('Max ST depression of people who have Cardiovascular disease: ', max(df[df['target'] == 2]['oldpeak']))
print('Average ST depression of people not have Cardiovascular disease: ', df[df['target'] == 2]['oldpeak'].mean())
# Out:
# Min ST depression of people who have Cardiovascular disease:  0.0
# Max ST depression of people who have Cardiovascular disease:  6.2
# Average ST depression of people not have Cardiovascular disease:  1.584166666666667

# %% [markdown]
# **Note:**
#
# The average ST depression of people who do not have heart disease is 0.6 and the average ST depression of people have heart disease is 1.5.

# %% [markdown]
# ### Slope Exploration

# %%
# Display slope of the peak exercise ST segment in bar chart
df.groupby(df['slope']).count()['target'].plot(kind = 'bar', title = 'Slope of the Peak Exercise ST Segment', figsize = (8, 6))
plt.xticks(np.arange(3), ('upsloping', 'flat', 'downsloping'), rotation = 0)
plt.show()

# %%
# Display slope of the peak exercise ST segment based on the target
pd.crosstab(df.slope,df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Cardiovascular Disease Frequency According to Slope of the Peak Exercise ST Segment')
plt.xlabel('Slope')
plt.xticks(np.arange(3), ('upsloping', 'flat', 'downsloping'), rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Note:**
#
# As it is clear, the people with flat peak ST segment are likely to have heart disease and usually the people who do not have heart disease have upsloping peak ST segment.

# %% [markdown]
# ### Major Vessels Exploration

# %%
# Display number of major vessels in bar chart
df.groupby(df['ca']).count()['target'].plot(kind = 'bar', title = 'Number of Major Vessels Colored by Flourosopy', 
                                            figsize = (8, 6))
plt.show()

# %%
# Display number of vessels based on the target
pd.crosstab(df.ca,df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Cardiovascular Disease Frequency According to Number of Major Vessels Colored by Flourosopy')
plt.xlabel('number of vessels')
plt.xticks(rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Note:**
#
# As it is clear, the people who do not have heart disease usually do not have major vessels colored by flourosopy.

# %% [markdown]
# ### Thalassemia Exploration

# %%
# Display thalassemia in bar chart
df.groupby(df['thal']).count()['target'].plot(kind = 'bar', title = 'Thalassemia')
plt.xticks(np.arange(3), ('normal', 'fixed defect', 'reversible defect'), rotation = 0)
plt.show()

# %%
pd.crosstab(df.thal,df.target).plot(kind = "bar", figsize = (8, 6))
plt.title('Cardiovascular Disease Frequency According to Thalassemia')
plt.xlabel('Thalassemia')
plt.xticks(np.arange(3), ('normal', 'fixed defect', 'reversible defect'), rotation = 0)
plt.ylabel('Frequency')
plt.show()

# %% [markdown]
# **Note:**
#
# As it is clear, the people with reversible defect are likely to have Cardiovascular disease.

# %% [markdown]
# ### The correlation between Cardiovascular disease, cp and exang

# %%
# g = sns.catplot("cp", col = "exang", col_wrap = 3, data = df[df['target'] == 1], kind = "count")
# plt.xticks(np.arange(4), ('typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic'), rotation = 0)
# g.fig.suptitle('People without Heart Disease', y = 1.1)
# plt.show()

# %%
# g = sns.catplot("cp", col = "exang", col_wrap = 3, data = df[df['target'] == 2], kind = "count")
# plt.xticks(np.arange(4), ('typical angina', 'atypical angina', 'non-anginal pain', 'asymptomatic'), rotation = 0)
# g.fig.suptitle('People with Heart Disease', y = 1.1)
# plt.show()

# %% [markdown]
# **Note:**
#
# The people who have exercise induced angina, they usually suffer from asymptomatic chest pain. Moreover, the people who do not have exercise induced angina, they usually suffer from asymptomatic chest pain if they have Cardiovascular disease.

# %% [markdown]
# ### The correlation between oldpeak, slope and target

# %%
sns.catplot(x = "slope", y = "oldpeak", hue = "target", data = df)
plt.title('The correlation between oldpeak and slope')
plt.xticks(np.arange(3), ('upsloping', 'flat', 'downsloping'), rotation = 0)
plt.show()

# %% [markdown]
# **Note:**
#
# Flat slope and downsloping have higher values of ST depression.

# %% [markdown]
# ### The correlation between ca and age

# %%
g = sns.catplot(x = 'ca', y = 'age', hue = 'target', data = df, kind="swarm")
g.fig.suptitle('The correlation between number of major vessels colored by flourosopy and age', y = 1.1)
plt.show()

# %% [markdown]
# **Note:**
#
# The older people are more likely to have vessels colored by flourosopy.

# %% [markdown]
# ### The correlation between age and thalach

# %%
sns.relplot(x = 'age', y = 'thalach', data = df, hue = 'target', legend="full")
plt.title('The correlation between age and heart rate')
plt.show()

# %% [markdown]
# **Note:**
#
# The older the person, the lower the heart rate. Also, the people with lower heart rate are likely to have Cardiovascular disease.

# %% [markdown]
# ## 3. Modeling

# %% [markdown]
# ### 3.1. Prepare Data for Machine Learning

# %%
# Initialize data and target
target = df['target']
features = df.drop(['target'], axis = 1)

# %%
# Split the data into training set and testing set
X_train, X_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 0)

# %% [markdown]
# Here, I will use the below machine learning algorithms then I will select the best one based on its classification report.
#
# * Support Vector Machine
# * Random Forest
# * Ada Boost
# * Gradient Boosting

# %% [markdown]
# ### 3.2. Train and Evaluate Models

# %%
# Train and evaluate model
def fit_eval_model(model, train_features, y_train, test_features, y_test):
    
    """
    Function: train and evaluate a machine learning classifier.
    Args:
      model: machine learning classifier
      train_features: train data extracted features
      y_train: train data lables
      test_features: train data extracted features
      y_test: train data lables
    Return:
      results(dictionary): a dictionary of classification report
    """
    results = {}
    
    # Train the model
    model.fit(train_features, y_train)
    
    # Test the model
    train_predicted = model.predict(train_features)
    test_predicted = model.predict(test_features)
    
     # Classification report and Confusion Matrix
    results['classification_report'] = classification_report(y_test, test_predicted)
    results['confusion_matrix'] = confusion_matrix(y_test, test_predicted)
        
    return results

# %%
# Initialize the models
sv = SVC(random_state = 1)
rf = RandomForestClassifier(random_state = 1)
ab = AdaBoostClassifier(random_state = 1)
gb = GradientBoostingClassifier(random_state = 1)


# Fit and evaluate models
results = {}
for cls in [sv, rf, ab, gb]:
    cls_name = cls.__class__.__name__
    results[cls_name] = {}
    results[cls_name] = fit_eval_model(cls, X_train, y_train, X_test, y_test)

# %%
# Print classifiers results
for result in results:
    print (result)
    print()
    for i in results[result]:
        print (i, ':')
        print(results[result][i])
        print()
    print ('-----')
    print()
# Out:
# SVC
#
# classification_report :
#               precision    recall  f1-score   support
#
#            1       0.71      0.90      0.79        30
#            2       0.81      0.54      0.65        24
#
#     accuracy                           0.74        54
#    macro avg       0.76      0.72      0.72        54
# weighted avg       0.76      0.74      0.73        54
#
#
# confusion_matrix :
# [[27  3]
#  [11 13]]
#
# -----
#
# RandomForestClassifier
#
# classification_report :
#               precision    recall  f1-score   support
#
#            1       0.76      0.73      0.75        30
#            2       0.68      0.71      0.69        24
#
#     accuracy                           0.72        54
#    macro avg       0.72      0.72      0.72        54
# weighted avg       0.72      0.72      0.72        54
#
#
# confusion_matrix :
# [[22  8]
#  [ 7 17]]
#
# -----
#
# AdaBoostClassifier
#
# classification_report :
#               precision    recall  f1-score   support
#
#            1       0.75      0.80      0.77        30
#            2       0.73      0.67      0.70        24
#
#     accuracy                           0.74        54
#    macro avg       0.74      0.73      0.73        54
# weighted avg       0.74      0.74      0.74        54
#
#
# confusion_matrix :
# [[24  6]
#  [ 8 16]]
#
# -----
#
# GradientBoostingClassifier
#
# classification_report :
#               precision    recall  f1-score   support
#
#            1       0.79      0.73      0.76        30
#            2       0.69      0.75      0.72        24
#
#     accuracy                           0.74        54
#    macro avg       0.74      0.74      0.74        54
# weighted avg       0.74      0.74      0.74        54
#
#
# confusion_matrix :
# [[22  8]
#  [ 6 18]]
#
# -----

# %% [markdown]
# #### Selecting the Classifier
# From the results, the best classifier is GradientBoostingClassifier.

# %% [markdown]
# ### 3.3. The Important Features

# %%
# get importance
importance = gb.feature_importances_
# summarize feature importance
for i,v in enumerate(importance):
    print('Feature: %s, Score: %.5f' % (features.columns[i], v))
# plot feature importance
plt.bar([x for x in range(len(importance))], importance)
plt.show()
# Out:
# Feature: age, Score: 0.06003
# Feature: sex, Score: 0.01170
# Feature: cp, Score: 0.28587
# Feature: trestbps, Score: 0.03719
# Feature: chol, Score: 0.06027
# Feature: fbs, Score: 0.00082
# Feature: restecg, Score: 0.00376
# Feature: thalach, Score: 0.06526
# Feature: exang, Score: 0.02465
# Feature: oldpeak, Score: 0.13452
# Feature: slope, Score: 0.04946
# Feature: ca, Score: 0.17047
# Feature: thal, Score: 0.09600

# %%
# Train and evaluate model
def fit_eval_model(model, train_features, y_train, test_features, y_test):
    
    
    results = {}
    
    # Train the model
    model.fit(train_features, y_train)
    
    # Test the model
    train_predicted = model.predict(train_features)
    test_predicted = model.predict(test_features)
    
     # Classification report and Confusion Matrix
    results['classification_report'] = classification_report(y_test, test_predicted)
    results['confusion_matrix'] = confusion_matrix(y_test, test_predicted)
        
    return results

# %% [markdown]
# ### 3.4. Save Model
#
#  Finally, I will save the GradientBoostingClassifier model to use it later.

# %%
# Save the model as serialized object pickle
with open('model.pkl', 'wb') as file:
    pickle.dump(gb, file)
